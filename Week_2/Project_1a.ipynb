# %% [markdown]
# ![Screenshot 2026-03-11 161138.png](attachment:8f8e0c68-e290-4cdb-9819-d3c1ae32765c.png)

# %% [raw]
# PSEUDOCODE
# BEGIN
# INPUT goods
# INPUT quantity of goods
# COMPUTE Total price = goods * quantity of goods
# DISPLAY Total price
# INPUT payment method
# DISPLAY receipt
# PRINT receipt
# END
